# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df_example = pd.read_csv('/content/drive/MyDrive/electricity_forecast/Database.csv', index_col=1, parse_dates=True)

# %%
df_example = df_example['Electric_demand']
df_selected = df_example.resample('60T').sum()
df_selected.index = pd.to_datetime(df_selected.index)
# Out:
# <ipython-input-10-e39a3ff85922>:2: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df_selected = df_example.resample('60T').sum()

# %%
df_selected.index
# Out:
# DatetimeIndex(['2019-01-01 00:00:00', '2019-01-01 01:00:00',
#                '2019-01-01 02:00:00', '2019-01-01 03:00:00',
#                '2019-01-01 04:00:00', '2019-01-01 05:00:00',
#                '2019-01-01 06:00:00', '2019-01-01 07:00:00',
#                '2019-01-01 08:00:00', '2019-01-01 09:00:00',
#                ...
#                '2021-12-31 14:00:00', '2021-12-31 15:00:00',
#                '2021-12-31 16:00:00', '2021-12-31 17:00:00',
#                '2021-12-31 18:00:00', '2021-12-31 19:00:00',
#                '2021-12-31 20:00:00', '2021-12-31 21:00:00',
#                '2021-12-31 22:00:00', '2021-12-31 23:00:00'],
#               dtype='datetime64[ns]', name='Time', length=26304, freq='60min')

# %%
df_selected.index = pd.to_datetime(df_selected.index, errors='coerce')

# Create new features based on the index
df_selected['day_of_the_month'] = df_selected.index.day
df_selected['hours_of_the_day'] = df_selected.index.hour  # Extracts the hour from the datetime index
df_selected['Day_of_the_week'] = df_selected.index.dayofweek
df_selected['days_from_start'] = (df_selected.index - df_selected.index[0]).days
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-6c4c5a2e7241> in <cell line: 5>()
#       3 # Create new features based on the index
#       4 df_selected['day_of_the_month'] = df_selected.index.day
# ----> 5 df_selected['hours_of_the_day'] = df_selected.index.hour  # Extracts the hour from the datetime index
#       6 df_selected['Day_of_the_week'] = df_selected.index.dayofweek
#       7 df_selected['days_from_start'] = (df_selected.index - df_selected.index[0]).days
#
# AttributeError: 'Index' object has no attribute 'hour'

# %%
df_selected.head()

# %%
selected_columns = ['Time', 'Season', 'Day_of_the_week', 'Electric_demand']
df_selected = df_example[selected_columns]

# %%
df_selected.head()

# %%
# Convert the index to a datetime format if it is not already
df_selected.index = pd.to_datetime(df_selected['Time'])

# Create new features
df_selected['day_of_the_month'] = df_selected.index.day
df_selected['hours_of_the_day'] = df_selected.index.hour
df_selected['minutes_of_the_hour'] = df_selected.index.minute

# %%
df_selected

# %%
df_selected.drop('Time', axis=1, inplace=True)

# %%
df_selected['days_from_start'] = (df_selected.index - df_selected.index[0]).days

# %%
df_selected.iloc[-8700:-300,:]

# %%
df_selected

# %%
df_selected['id'] = 'MT001'

# %%
df_selected['hours_from_start'] = (df_selected.index - df_selected.index[0]).total_seconds() / 3600

# %%
df_selected.to_csv('/content/drive/MyDrive/electricity_forecast/src/data_example/data/example/Database_selected.csv')

# %%
df_selected.to_csv('/content/drive/MyDrive/electricity_forecast/src/outputs/data/example/Database_selected.csv')
